# %% [markdown]
# # Data collection of soccer players

# %% [markdown]
# ## Libraries

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
#from tqdm import tqdm
from tqdm.notebook import trange, tqdm
import time 
import csv
import re

# %% [markdown]
# ##Functions

# %% [markdown]
# ### id

# %%
def player_id(link):
  try:
    player_id = (str(link).split('/'))[-1]
    return player_id
  except:
    print(link+" player id not found!")
    return np.nan

# %% [markdown]
# ### name and lastname

# %%
def player_name (page_content,link):
  try:
    #get the name tag
    full_name = page_content.find('h1',class_='data-header__headline-wrapper').get_text()
    #Remove extra space
    full_name = (" ".join(full_name.strip().split()))
    #Separating name and last name
    full_name = re.sub(r'#\d+','', full_name).strip()
    name = full_name.split(' ')[0]
    last_name = full_name.split(' ')[-1]

    return full_name
    #return name, last_name
    #print(full_name,'\n'+name ,'\n'+last_name)
  
  except:
    print(link+" player name not found!")
    return np.nan

# %% [markdown]
# ### Place of birth

# %%
def place_of_birth(page_content, link):
  try:
    place_of_birth = page_content.find(['span'], string=['Place of birth:']).find_next('img')['title']
    return place_of_birth

  except:
    print(link+" player place of birth not found!")
    return np.nan

# %% [markdown]
# ### Date of birth (age)

# %%
# date of birth
def date_of_birth(page_content, link):
  try:
    date_of_birth = page_content.find(['span'], string=['Date of birth:']).find_next('span').text
    date_of_birth = date_of_birth.strip().replace(',','').split(' ')
    month = date_of_birth[0]
    day = date_of_birth[1]
    year = date_of_birth[2]
    #print(year, '\n'+month, '\n'+day)
    return date_of_birth
  
  except:
    print(link+" player date of birth not found!")
    return np.nan

# %%
# age
def player_age(page_content, link):
  try:
    age = page_content.find(['span'], string=['Age:']).find_next('span').text
    #print(age)
    return age
  
  except:
    print(link+" player age of birth not found!")
    return np.nan

# %% [markdown]
# ### height

# %%
def player_height (page_content, link):
  try:
    height = page_content.find(['span'], string=['Height:']).find_next('span').text
    #cleaning the text and cast it to int
    height = int(height.replace(',','').replace('m','').strip())
    #print(height)
    return height
  
  except:
    print(link+" player height not found!")
    return np.nan

# %% [markdown]
# ### citizenship

# %%
def player_citizenship (page_content, link):
  try:
    citizenship = page_content.find(['span'], string=['Citizenship:']).find_next('span').text #all citizenships
    #print(citizanship.strip())
    citizenship = citizenship.strip().split('\xa0')
    return citizenship[0].strip() # first citizenship
  
  except:
    print(link+" player citizenship not found!")
    return np.nan

# %% [markdown]
# ### position

# %%
def player_position (page_content, link):
  try:
    position = page_content.find(['span'], string=['Position:']).find_next('span').text
    #cleaning the text 
    position = position.replace('-',' ')
    position = (" ".join(position.strip().split()))
    #print(position)
    return position
  
  except:
    print(link+" player position not found!")
    return np.nan

# %% [markdown]
# ### foot

# %%
def player_foot (page_content, link):
  try:
    foot = page_content.find(['span'], string=['Foot:']).find_next('span').text
    #print(foot.strip())
    return foot
  
  except:
    print(link+" player foot not found!")
    return np.nan

# %% [markdown]
# ### player agent

# %%
def player_agent (page_content, link):
  try:
    player_agent = page_content.find(['span'], string=['Player agent:']).find_next('span').text
    #print(player_agent.strip())
    return player_agent.strip()
  
  except:
    print(link+" player agent not found!")
    return np.nan

# %% [markdown]
# ### current club

# %%
def current_club(page_content, link):
  try:
    club_name = page_content.find('div', class_='data-header__club-info').find('span', class_='data-header__club').text
    #club_name = page.find('div', class_='data-header__club-info').find('span', class_='data-header__club').find('a')['title'] full name of club
    return club_name.strip()
  except:
    print(link+" current club not found!")
    return np.nan

# %% [markdown]
# ### Detailed performance data

# %% [markdown]
# #### cast the table in website to pandas data frame to get more information

# %%
def detail_page_request(player_id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  #print (detail_link_format.format(id))
  detail_page=''
  try:
    detail_page = requests.get(detail_link_format.format(player_id), headers=headers)
    detail_page = BeautifulSoup(detail_page.content, 'html.parser') 
    return detail_page 
  except:
    print(detail_link_format.format(player_id)+" player detailed performance link not found!")
    return np.nan

# %%
def create_player_detial_dataframe (id): # id is for returning an eeror 
  detail_page = detail_page_request(id)
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  # find table in html
  try:
    table = detail_page.find('table', class_='items')
  except:
    print(detail_link_format.format(id)+" detail table not found!")

  # find column names
  column_values=['player_id']
  try:
    header = detail_page.find('table', class_='items').find('thead').find('tr').find_all('th')
    for th in header:
      if th['id'] == 'yw1_c2':
        continue
      try:
        column_values.append(th.find('a').find('span')['title'])
      except:
        column_values.append(th.text)
    #print(column_values)
  except:
    print(detail_link_format.format(id)+" table column_value found!")

  # creat data frame 
  detail_table= pd.DataFrame(columns = column_values)

  # find table rows and add to dataframe 
  try:
    rows = detail_page.find('table', class_='items').find('tbody').find_all('tr')
    for row in rows:
      table_row = []
      table_row.append(id)
      for section in row.find_all('td'):
        if section.text !='':
          table_row.append(section.text)
        else:
          try:
            table_row.append(section.a['title'])
          except:
            continue
      detail_table.loc[len(detail_table.index)]= table_row  
  except:
    print(detail_link_format.format(id)+" table row not found!")
  
  seasons = ['21/22', '20/21', '19/20', '18/19', '17/18', '16/17', '15/16']
  detail_2015_2021 = detail_table[detail_table['Season'].isin(seasons)] 

  return detail_2015_2021

  #find total row and add to dataframe
  '''
  total = []
  try:
    total_row = detail_page.find('table', class_='items').find('tfoot').find('tr').find_all('td')
    for row in total_row:
      try: 
        row['class']
        total.append(row.text)
      except:
        continue
  except:
    print(detail_link_format.format(id)+" total row not found!")
  detail_table.loc[len(detail_table.index)]= total
  '''
  #return detail_table

# %%
def detial_total_row(id):
  detail_page = detail_page_request(id)
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  total = []
  try:
    total_row = detail_page.find('table', class_='items').find('tfoot').find('tr').find_all('td')
    for row in total_row:
      try: 
        row['class']
        total.append(row.text)
      except:
        continue
  except:
    print(detail_link_format.format(id)+" total row not found!")
  return total

# %%
print(detial_total_row('17965'))
# Out:
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/17965/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 player detailed performance link not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/17965/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total row not found!
# []

# %% [markdown]
# #### goals scored

# %%
def goals_scored (id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  try:
    return detial_total_row(id)[6]
  except:
    print(detail_link_format.format(id)+" goals scored not found!")
    return 'nan'

# %% [markdown]
# #### goals assisted

# %%
def goals_assisted (id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  try:
    return detial_total_row(id)[7]
  except:
    print(detail_link_format.format(id)+" goals assisted not found!")
    return 'nan'

# %% [markdown]
# #### total appearance

# %%
def total_appearance (id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  try:
    return detial_total_row(id)[4]
  except:
    print(detail_link_format.format(id)+" total appearance not found!")
    return 'nan'

# %% [markdown]
# #### goals_conceded

# %%
def goals_conceded (id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  try:
    return detial_total_row(id)[13]
  except:
    print(detail_link_format.format(id)+" goals conceded not found!")
    return 'nan'

# %% [markdown]
# #### clean_sheets

# %%
def clean_sheets (id):
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  try:
    return detial_total_row(id)[14]
  except:
    print(detail_link_format.format(id)+" clean sheats not found!")
    return 'nan'

# %% [markdown]
# #### yello cards

# %%
#print(total[11])

# %% [markdown]
# #### second yellow cards

# %%
#print (total[12])

# %% [markdown]
# #### red cards

# %%
#print (total[13])

# %% [markdown]
# ### transfer history

# %%
# creating a dataframe with the transfer history table 
def player_transfer_history_dataframe(page_content, link):
  try:
    html_transfer_table = page_content.find('div', class_='grid tm-player-transfer-history-grid tm-player-transfer-history-grid tm-player-transfer-history-grid--heading')
  except:
    print(link+" transfer table not found!")

  # create columns
  transfer_table_column= []
  transfer_table_column = html_transfer_table.text.split()
  transfer_table_column.append('player_id')
  #print(transfer_table_column)

  #create rows
  transfer_table_rows = []
  try:
    html_transfer_table_rows = page_content.find_all('div', class_='grid tm-player-transfer-history-grid')
    for row in html_transfer_table_rows:
      row= row.text
      #delete extra spaces
      row = re.sub(' +', '', row)
      #divide columns by \n
      row = row.split('\n')
      #delete empty strings from list
      row = list(filter(None, row))
      row.append(player_id(link))
      
      #
      transfer_table_rows.append(row)
  except:
    print(link+" transfer table rows not found!")
  
  transfer_table = pd.DataFrame(transfer_table_rows, columns =transfer_table_column)
  seasons = ['21/22', '20/21', '19/20', '18/19', '17/18', '16/17', '15/16']
  transfer_2015_2021 = transfer_table[transfer_table['Season'].isin(seasons)] 
  return transfer_2015_2021

# %% [markdown]
# ##Crawler header

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (HTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36',
    'Accept-Language' : 'en-US,en;q=0.9'
}

# %% [markdown]
# ## Player information

# %%
def player_info(page,link):
  info = []
  if player_position(page, link) == 'Goalkeeper':
    info.append(player_id(link))
    info.append(player_name(page, link))
    info.append(date_of_birth(page, link))
    info.append(player_height(page, link))
    info.append(player_citizenship(page, link))
    info.append(player_position(page, link))
    info.append(player_foot(page, link))
    info.append(current_club(page, link))
    info.append(goals_scored(player_id(link)))
    info.append(goals_assisted(player_id(link)))
    info.append(goals_conceded(player_id(link)))
    info.append(clean_sheets(player_id(link)))
    info.append(total_appearance(player_id(link)))
    info.append(player_agent(page, link))
  
  else: 
    info.append(player_id(link))
    info.append(player_name(page, link))
    info.append(date_of_birth(page, link))
    info.append(player_height(page, link))
    info.append(player_citizenship(page, link))
    info.append(player_position(page, link))
    info.append(player_foot(page, link))
    info.append(current_club(page, link))
    info.append(goals_scored(player_id(link)))
    info.append(goals_assisted(player_id(link)))
    info.append('nan')
    info.append('nan')
    info.append(total_appearance(player_id(link)))
    info.append(player_agent(page, link))
    
  return info

# %% [markdown]
# ###Creating tables related to players

# %%
# player table
#player, transfer
def find_player_info(link):
  page = requests.get(link, headers=headers)
  time.sleep(2)
  page = BeautifulSoup(page.content, 'html.parser')
  #print(page.prettify)
  player = []
  player_club = []
  player_statistics= pd.DataFrame()
  transfer = pd.DataFrame()

  #player table
  player = player_info(page, link)
  
  #transfer table
  

  return player, player_transfer_history_dataframe(page, link) , create_player_detial_dataframe(player_id(link))

# %% [markdown]
# ##The process of finding the link of the players' page

# %% [markdown]
# ###1.Finding leagues of each season

# %%
# finding leagues of each season
def league_links (link):
  page = requests.get(link, headers=headers)
  page = BeautifulSoup(page.content, 'html.parser')
  #page.prettify
  leagues_link = []
  #filter leagues and cups that we want
  #leagues={'First Tier', 'Second Tier', 'Third Tier', 'Fourth Tier', 'Fifth Tier'}
  leagues={'First Tier'}
  tr_tags= page.find('table', class_= 'items').find('tbody').find_all('tr')
  flag = 2
  #for tr in tr_tags:

  for i, tr in enumerate(tr_tags):  
    #if i >1: 
      #break
    if(tr.find('td',class_='extrarow bg_blau_20 hauptlink') and tr.find('td',class_='extrarow bg_blau_20 hauptlink').text not in leagues):
      #print(tr.find('td',class_='extrarow bg_blau_20 hauptlink').text)
      flag =0
    elif (tr.find('td',class_='extrarow bg_blau_20 hauptlink') and tr.find('td',class_='extrarow bg_blau_20 hauptlink').text in leagues):
      flag = 1
    #if(tr.find('td', class_='hauptlink').find('tbody')):
    if(flag):
      try:
        lg_link = tr.find('td', class_='hauptlink').find('a')['href']
        #print(lg_link)
        leagues_link.append('https://www.transfermarkt.com'+lg_link)
      except:
        continue
  return leagues_link

# %% [markdown]
# ###2.Finding teams of each league

# %%
#find teams of each league 
def team_links(link): #link of the league teams page
  page = requests.get(link, headers=headers)
  page = BeautifulSoup(page.content, 'html.parser')
  try:
    team_tag = page.find('table', class_='items').find('tbody').find_all('tr')
  except:
    print(link+ ' team table not found!')
  team_link =[]
  for i, tr in enumerate(team_tag):
    #if i>2:
     #break
    try:
      team_link.append('https://www.transfermarkt.com'+tr.find('td').find_next('td').find('a')['href'])
    except:
      print(link+ ' team link not found')
      team_link.append(np.nan)
  
  return team_link

# %% [markdown]
# ###3.finding players of each team

# %%
# find players link by team link
def player_links(link): 
  page = requests.get(link, headers=headers)
  time.sleep(2)
  page = BeautifulSoup(page.content, 'html.parser')

  players_link=[]
  player_tag = page.find('table', class_='items').find('tbody').find_all('tr')
  for tr in player_tag:
    #if len(players_link)>9:
      #break
    try:
      player_link= tr.find('table', class_='inline-table').find('td', class_='hauptlink').find('div', class_='di nowrap').find('a')['href']
      players_link.append('https://www.transfermarkt.com'+ player_link)
    except:
      #print('player link not found')
      continue
    #print(player_name)
  
  return players_link

# %% [markdown]
# ##Crawling main code

# %%
country_season_link_format = 'https://www.transfermarkt.com/wettbewerbe/national/wettbewerbe/{}/saison_id/{}/plus/1'
country_id = {'189', '50', '157', '40', '75'} #England, France, Spain, Germany, Italy
#country_id = {'189'} #England, France
season = {'2021', '2020', '2019', '2018', '2017', '2016', '2015'}

#link variables
all_season_leagues=[]
all_league_teams={}
all_team_players={}

#test variables
player_ids=[]
player_count=0

#final tables culomns & Each player's table
player_table_culomns = ['player_id', 'name', 'birth_date', 'height', 'current_international', 'main_position', 'foot', 'current_club', 'goals_scored', 'goals_assisted', 'goals_conceded', 'clean_sheets', 'total_appearence', 'agent']
transfer_table_culomns = ['player_id', 'Season', 'Date', 'Left', 'Joined', 'MV', 'Fee']

player = pd.DataFrame(columns = player_table_culomns)
transfer = pd.DataFrame(columns = transfer_table_culomns)
statistics = pd.DataFrame()

#final tables (all datas from players)
player_table = pd.DataFrame(columns = player_table_culomns)
transfer_table = pd.DataFrame(columns = transfer_table_culomns)
statistics_table = pd.DataFrame()


for c_id in tqdm(country_id, desc ="countries"):
  
  for i, s_id in enumerate(season):
    link = country_season_link_format.format(c_id, s_id)
    
    all_season_leagues=(league_links(link))
    #print('----- leagues links',all_season_leagues)
    
    for league_link in tqdm(all_season_leagues, desc='leagues'):
      #print(league_link)
      all_league_teams=(team_links(league_link))
      
      for team_link in tqdm(all_league_teams, desc='teams'):  
       
        all_team_players=(player_links(team_link))
        for player_link in (all_team_players):
        
          try:
            if player_id(player_link) not in player_ids:
              player_count+=1
              #print ('new id added','   ',player_count,'  ', player_id(player_link))
              player_ids.append(player_id(player_link))
              #player, transfer = find_player_info(player_link)
              player, transfer, statistics = find_player_info(player_link)
              
              player_table.loc[len(player_table.index)]= player
              transfer_table = pd.concat([transfer_table, transfer], axis=0,  ignore_index = True)
              statistics_table = pd.concat([statistics_table, statistics], axis=0,  ignore_index = True)

            else:
              print(player_link + ' duplicate id found and skiped')
            continue
          except:
            print(player_link + ' something wrong and skiped')           
            continue
          


player_table.to_csv('player_table.csv', encoding='utf-8')
transfer_table.to_csv('trasnfer_table.csv', encoding='utf-8')
statistics_table.to_csv('statistics_table.csv', encoding='utf-8')
#df.to_csv(file_name, sep='\t', encoding='utf-8')
# Out:
# countries:   0%|          | 0/5 [00:00<?, ?it/s]
# leagues:   0%|          | 0/1 [00:00<?, ?it/s]
# teams:   0%|          | 0/20 [00:00<?, ?it/s]
# https://www.transfermarkt.com/andrea-barzagli/profil/spieler/7109 player agent not found!
# https://www.transfermarkt.com/alex-sandro/profil/spieler/79960 player agent not found!
# https://www.transfermarkt.com/patrice-evra/profil/spieler/5285 player agent not found!
# https://www.transfermarkt.com/paolo-de-ceglie/profil/spieler/44709 player agent not found!
# https://www.transfermarkt.com/stefano-sturaro/profil/spieler/167859 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 goals assisted not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total appearance not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table column_value found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/93128/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/kalidou-koulibaly/profil/spieler/93128 something wrong and skiped
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player position not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player name not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player date of birth not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player height not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player citizenship not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player position not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player foot not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 current club not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 player agent not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 something wrong and skiped
# https://www.transfermarkt.com/sebastiano-luperto/profil/spieler/278531 player agent not found!
# https://www.transfermarkt.com/ivan-strinic/profil/spieler/39799 player agent not found!
# https://www.transfermarkt.com/allan/profil/spieler/126422 player agent not found!
# https://www.transfermarkt.com/mirko-valdifiori/profil/spieler/84903 player agent not found!
# https://www.transfermarkt.com/alessio-zerbin/profil/spieler/433584 player agent not found!
# https://www.transfermarkt.com/lorenzo-crisanto/profil/spieler/340430 player agent not found!
# https://www.transfermarkt.com/stefano-ciavattini/profil/spieler/265075 player height not found!
# https://www.transfermarkt.com/bruno-peres/profil/spieler/148751 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/24977/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/abdullahi-nura/profil/spieler/337705 player agent not found!
# https://www.transfermarkt.com/radja-nainggolan/profil/spieler/41982 player agent not found!
# https://www.transfermarkt.com/gerson/profil/spieler/341705 player agent not found!
# https://www.transfermarkt.com/mohamed-salah/profil/spieler/148455 player agent not found!
# https://www.transfermarkt.com/francesco-totti/profil/spieler/5958 player agent not found!
# https://www.transfermarkt.com/jeison-murillo/profil/spieler/131102 player agent not found!
# https://www.transfermarkt.com/marco-andreolli/profil/spieler/36356 player agent not found!
# https://www.transfermarkt.com/senna-miangue/profil/spieler/249552 player agent not found!
# https://www.transfermarkt.com/alassane-traore/profil/spieler/336704 player agent not found!
# https://www.transfermarkt.com/loris-zonta/profil/spieler/377043 player agent not found!
# https://www.transfermarkt.com/ivan-perisic/profil/spieler/42460 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/39099/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/215390/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/jherson-vergara/profil/spieler/262972 player agent not found!
# https://www.transfermarkt.com/giorgio-altare/profil/spieler/354909 player agent not found!
# https://www.transfermarkt.com/mattia-el-hilali/profil/spieler/124203 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/20137/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/37918/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/hachim-mastour/profil/spieler/253267 player agent not found!
# https://www.transfermarkt.com/mbaye-niang/profil/spieler/157501 player agent not found!
# https://www.transfermarkt.com/luca-borrelli/profil/spieler/381284 player height not found!
# https://www.transfermarkt.com/luca-borrelli/profil/spieler/381284 player foot not found!
# https://www.transfermarkt.com/luca-borrelli/profil/spieler/381284 player agent not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player position not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player name not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player date of birth not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player height not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player citizenship not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player position not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player foot not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 current club not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/240260/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/240260/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 goals scored not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/240260/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 total row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/240260/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 goals assisted not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 player agent not found!
# https://www.transfermarkt.com/franjo-prce/profil/spieler/240260 something wrong and skiped
# https://www.transfermarkt.com/luca-germoni/profil/spieler/339566 player agent not found!
# https://www.transfermarkt.com/giorgio-spizzichino/profil/spieler/391933 player agent not found!
# https://www.transfermarkt.com/lucas-biglia/profil/spieler/26721 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/55957/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/senad-lulic/profil/spieler/61449 player agent not found!
# https://www.transfermarkt.com/brayan-perea/profil/spieler/188498 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/188498/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/davide-astori/profil/spieler/87210 current club not found!
# https://www.transfermarkt.com/davide-astori/profil/spieler/87210 player agent not found!
# https://www.transfermarkt.com/riccardo-baroni/profil/spieler/398025 player agent not found!
# https://www.transfermarkt.com/fabio-maistro/profil/spieler/398031 player agent not found!
# https://www.transfermarkt.com/matias-fernandez/profil/spieler/37918 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/36371/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/domenico-coppola/profil/spieler/393489 player agent not found!
# https://www.transfermarkt.com/alberto-reinaudo/profil/spieler/440869 player height not found!
# https://www.transfermarkt.com/alberto-reinaudo/profil/spieler/440869 player foot not found!
# https://www.transfermarkt.com/alberto-reinaudo/profil/spieler/440869 player agent not found!
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 duplicate id found and skiped
# https://www.transfermarkt.com/luca-rossettini/profil/spieler/60128 player agent not found!
# https://www.transfermarkt.com/emiliano-moretti/profil/spieler/5755 player agent not found!
# https://www.transfermarkt.com/simone-auriletto/profil/spieler/265072 player agent not found!
# https://www.transfermarkt.com/alessio-benedetti/profil/spieler/312752 player agent not found!
# https://www.transfermarkt.com/andrea-sana/profil/spieler/397824 player height not found!
# https://www.transfermarkt.com/andrea-sana/profil/spieler/397824 player foot not found!
# https://www.transfermarkt.com/andrea-sana/profil/spieler/397824 player agent not found!
# https://www.transfermarkt.com/bruno-peres/profil/spieler/148751 duplicate id found and skiped
# https://www.transfermarkt.com/mirko-valdifiori/profil/spieler/84903 duplicate id found and skiped
# https://www.transfermarkt.com/giuseppe-vives/profil/spieler/42345 player agent not found!
# https://www.transfermarkt.com/kader-kouakou/profil/spieler/405197 player height not found!
# https://www.transfermarkt.com/kader-kouakou/profil/spieler/405197 player foot not found!
# https://www.transfermarkt.com/juan-iturbe/profil/spieler/81455 duplicate id found and skiped
# https://www.transfermarkt.com/iago-falque/profil/spieler/59340 player height not found!
# https://www.transfermarkt.com/andrea-belotti/profil/spieler/167727 player agent not found!
# https://www.transfermarkt.com/manuel-de-luca/profil/spieler/375816 player agent not found!
# https://www.transfermarkt.com/marco-sportiello/profil/spieler/199976 duplicate id found and skiped
# https://www.transfermarkt.com/etrit-berisha/profil/spieler/77825 duplicate id found and skiped
# https://www.transfermarkt.com/davide-bassi/profil/spieler/41914 player agent not found!
# https://www.transfermarkt.com/francesco-rossi/profil/spieler/126634 player agent not found!
# https://www.transfermarkt.com/stefano-mazzini/profil/spieler/346528 player agent not found!
# https://www.transfermarkt.com/roberto-taliento/profil/spieler/392951 player agent not found!
# https://www.transfermarkt.com/ervin-zukanovic/profil/spieler/44059 player agent not found!
# https://www.transfermarkt.com/boukary-drame/profil/spieler/33442 player agent not found!
# https://www.transfermarkt.com/abdoulay-konko/profil/spieler/22139 player agent not found!
# https://www.transfermarkt.com/carlos-carmona/profil/spieler/76387 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/76387/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/roberto-gagliardini/profil/spieler/197471 duplicate id found and skiped
# https://www.transfermarkt.com/alberto-grassi/profil/spieler/197473 duplicate id found and skiped
# https://www.transfermarkt.com/giulio-migliaccio/profil/spieler/21756 player agent not found!
# https://www.transfermarkt.com/cristian-raimondi/profil/spieler/22249 player agent not found!
# https://www.transfermarkt.com/bryan-cabezas/profil/spieler/312735 player agent not found!
# https://www.transfermarkt.com/guido-marilungo/profil/spieler/61786 player agent not found!
# https://www.transfermarkt.com/francesco-scavo/profil/spieler/396768 player height not found!
# https://www.transfermarkt.com/francesco-scavo/profil/spieler/396768 player foot not found!
# https://www.transfermarkt.com/francesco-scavo/profil/spieler/396768 player agent not found!
# https://www.transfermarkt.com/lorenzo-ariaudo/profil/spieler/84921 player agent not found!
# https://www.transfermarkt.com/leonardo-sarzi-maddidini/profil/spieler/368373 player height not found!
# https://www.transfermarkt.com/leonardo-sarzi-maddidini/profil/spieler/368373 player foot not found!
# https://www.transfermarkt.com/leonardo-sarzi-maddidini/profil/spieler/368373 player agent not found!
# https://www.transfermarkt.com/alfred-duncan/profil/spieler/184894 player agent not found!
# https://www.transfermarkt.com/karim-laribi/profil/spieler/124911 player agent not found!
# https://www.transfermarkt.com/giovanni-sbrissa/profil/spieler/284636 player agent not found!
# https://www.transfermarkt.com/davide-biondini/profil/spieler/22186 player agent not found!
# https://www.transfermarkt.com/federico-ricci/profil/spieler/198086 duplicate id found and skiped
# https://www.transfermarkt.com/simone-caputo/profil/spieler/390732 player height not found!
# https://www.transfermarkt.com/simone-caputo/profil/spieler/390732 player agent not found!
# https://www.transfermarkt.com/christian-puggioni/profil/spieler/48003 player agent not found!
# https://www.transfermarkt.com/pietro-cavagnaro/profil/spieler/372134 player height not found!
# https://www.transfermarkt.com/pietro-cavagnaro/profil/spieler/372134 player foot not found!
# https://www.transfermarkt.com/pietro-cavagnaro/profil/spieler/372134 player agent not found!
# https://www.transfermarkt.com/gergely-hutvagner/profil/spieler/463775 player agent not found!
# https://www.transfermarkt.com/matias-silvestre/profil/spieler/20003 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/20003/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/luka-krajnc/profil/spieler/138584 player agent not found!
# https://www.transfermarkt.com/lorenzo-de-silvestri/profil/spieler/33571 duplicate id found and skiped
# https://www.transfermarkt.com/jacopo-sala/profil/spieler/96806 player agent not found!
# https://www.transfermarkt.com/mirko-eramo/profil/spieler/61783 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/136605/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/diego-faccioli/profil/spieler/348676 player agent not found!
# https://www.transfermarkt.com/ezequiel-munoz/profil/spieler/75127 player foot not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/75127/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/davide-brivio/profil/spieler/38824 duplicate id found and skiped
# https://www.transfermarkt.com/francesco-renzetti/profil/spieler/84845 player agent not found!
# https://www.transfermarkt.com/aleandro-rosi/profil/spieler/34239 player agent not found!
# https://www.transfermarkt.com/riccardo-fiamozzi/profil/spieler/197745 player agent not found!
# https://www.transfermarkt.com/tomas-rincon/profil/spieler/75942 duplicate id found and skiped
# https://www.transfermarkt.com/danilo-cataldi/profil/spieler/199733 duplicate id found and skiped
# https://www.transfermarkt.com/adel-taarabt/profil/spieler/45287 player agent not found!
# https://www.transfermarkt.com/nikola-ninkovic/profil/spieler/168944 player agent not found!
# https://www.transfermarkt.com/lucas-ocampos/profil/spieler/189441 duplicate id found and skiped
# https://www.transfermarkt.com/goran-pandev/profil/spieler/12563 player agent not found!
# https://www.transfermarkt.com/leonardo-pavoletti/profil/spieler/64793 duplicate id found and skiped
# https://www.transfermarkt.com/giovanni-simeone/profil/spieler/282388 player agent not found!
# https://www.transfermarkt.com/mauricio-pinilla/profil/spieler/6160 duplicate id found and skiped
# https://www.transfermarkt.com/luca-scordino/profil/spieler/397228 player foot not found!
# https://www.transfermarkt.com/luca-scordino/profil/spieler/397228 player agent not found!
# https://www.transfermarkt.com/danilo/profil/spieler/32816 player agent not found!
# https://www.transfermarkt.com/molla-wague/profil/spieler/129893 player agent not found!
# https://www.transfermarkt.com/gabriele-angella/profil/spieler/86793 player agent not found!
# https://www.transfermarkt.com/felipe/profil/spieler/17127 player agent not found!
# https://www.transfermarkt.com/yrondu-musavu-king/profil/spieler/170994 player agent not found!
# https://www.transfermarkt.com/alberto-parpinel/profil/spieler/386824 player foot not found!
# https://www.transfermarkt.com/alberto-parpinel/profil/spieler/386824 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/73786/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/edenilson/profil/spieler/169052 duplicate id found and skiped
# https://www.transfermarkt.com/panagiotis-kone/profil/spieler/19636 player agent not found!
# https://www.transfermarkt.com/alassane-traore/profil/spieler/336704 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/49841/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/46477/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/alfred-gomis/profil/spieler/163568 duplicate id found and skiped
# https://www.transfermarkt.com/luca-rossettini/profil/spieler/60128 duplicate id found and skiped
# https://www.transfermarkt.com/daniele-gastaldello/profil/spieler/7096 player agent not found!
# https://www.transfermarkt.com/nicolo-cherubin/profil/spieler/56854 player agent not found!
# https://www.transfermarkt.com/deian-boldor/profil/spieler/239570 player agent not found!
# https://www.transfermarkt.com/archimede-morleo/profil/spieler/85066 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/184528/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/vasilios-torosidis/profil/spieler/24977 duplicate id found and skiped
# https://www.transfermarkt.com/luca-ceccarelli/profil/spieler/41994 player agent not found!
# https://www.transfermarkt.com/amadou-diawara/profil/spieler/355501 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/215616/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/474621/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/giordano-trovade/profil/spieler/395091 player agent not found!
# https://www.transfermarkt.com/franco-brienza/profil/spieler/16137 player agent not found!
# https://www.transfermarkt.com/anthony-mounier/profil/spieler/57110 duplicate id found and skiped
# https://www.transfermarkt.com/aaron-mattia-tabacchi/profil/spieler/353998 player agent not found!
# https://www.transfermarkt.com/umar-sadiq/profil/spieler/337715 duplicate id found and skiped
# https://www.transfermarkt.com/robert-acquafresca/profil/spieler/35703 player agent not found!
# https://www.transfermarkt.com/gabriel/profil/spieler/79242 duplicate id found and skiped
# https://www.transfermarkt.com/marco-storari/profil/spieler/19136 duplicate id found and skiped
# https://www.transfermarkt.com/roberto-colombo/profil/spieler/43411 player agent not found!
# https://www.transfermarkt.com/luca-ceppitelli/profil/spieler/102745 player agent not found!
# https://www.transfermarkt.com/luka-krajnc/profil/spieler/138584 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-volteggi/profil/spieler/420849 player height not found!
# https://www.transfermarkt.com/matteo-volteggi/profil/spieler/420849 player foot not found!
# https://www.transfermarkt.com/matteo-volteggi/profil/spieler/420849 player agent not found!
# https://www.transfermarkt.com/nicola-murru/profil/spieler/171399 player agent not found!
# https://www.transfermarkt.com/senna-miangue/profil/spieler/249552 duplicate id found and skiped
# https://www.transfermarkt.com/luca-bittante/profil/spieler/163062 player agent not found!
# https://www.transfermarkt.com/andrea-mastino/profil/spieler/395596 player agent not found!
# https://www.transfermarkt.com/panagiotis-tachtsidis/profil/spieler/62415 duplicate id found and skiped
# https://www.transfermarkt.com/nicolo-barella/profil/spieler/255942 player agent not found!
# https://www.transfermarkt.com/paolo-farago/profil/spieler/167796 player agent not found!
# https://www.transfermarkt.com/simone-padoin/profil/spieler/56703 player agent not found!
# https://www.transfermarkt.com/riccardo-taccori/profil/spieler/396359 player foot not found!
# https://www.transfermarkt.com/riccardo-taccori/profil/spieler/396359 player agent not found!
# https://www.transfermarkt.com/federico-serra/profil/spieler/162551 player agent not found!
# https://www.transfermarkt.com/victor-ibarbo/profil/spieler/92141 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/92141/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/marco-sau/profil/spieler/55801 player agent not found!
# https://www.transfermarkt.com/federico-melchiorri/profil/spieler/46060 player agent not found!
# https://www.transfermarkt.com/kwang-song-han/profil/spieler/402193 player foot not found!
# https://www.transfermarkt.com/kwang-song-han/profil/spieler/402193 player agent not found!
# https://www.transfermarkt.com/alberto-pelagotti/profil/spieler/56921 player agent not found!
# https://www.transfermarkt.com/maurizio-pugliesi/profil/spieler/22285 player agent not found!
# https://www.transfermarkt.com/uros-cosic/profil/spieler/94305 player agent not found!
# https://www.transfermarkt.com/federico-dimarco/profil/spieler/198116 player agent not found!
# https://www.transfermarkt.com/davide-seminara/profil/spieler/355048 player agent not found!
# https://www.transfermarkt.com/vincent-laurini/profil/spieler/94936 player agent not found!
# https://www.transfermarkt.com/luca-bittante/profil/spieler/163062 duplicate id found and skiped
# https://www.transfermarkt.com/lapo-carradori/profil/spieler/302486 player height not found!
# https://www.transfermarkt.com/lapo-carradori/profil/spieler/302486 player agent not found!
# https://www.transfermarkt.com/assane-diousse/profil/spieler/287635 player agent not found!
# https://www.transfermarkt.com/jose-mauri/profil/spieler/240958 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/331389/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/davide-buglio/profil/spieler/385379 player agent not found!
# https://www.transfermarkt.com/riccardo-saponara/profil/spieler/88909 duplicate id found and skiped
# https://www.transfermarkt.com/omar-el-kaddouri/profil/spieler/73097 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/56912/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/guido-marilungo/profil/spieler/61786 duplicate id found and skiped
# https://www.transfermarkt.com/roman-chanturia/profil/spieler/222330 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/141654/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/cesare-bovo/profil/spieler/5946 duplicate id found and skiped
# https://www.transfermarkt.com/guglielmo-stendardo/profil/spieler/22093 duplicate id found and skiped
# https://www.transfermarkt.com/francesco-forte/profil/spieler/382571 player foot not found!
# https://www.transfermarkt.com/francesco-forte/profil/spieler/382571 player agent not found!
# https://www.transfermarkt.com/ibrahima-diallo/profil/spieler/400931 player agent not found!
# https://www.transfermarkt.com/bryan-cristante/profil/spieler/199248 duplicate id found and skiped
# https://www.transfermarkt.com/francesco-mele/profil/spieler/364635 player agent not found!
# https://www.transfermarkt.com/piermarco-dangelo/profil/spieler/392550 player agent not found!
# https://www.transfermarkt.com/marco-pompetti/profil/spieler/459991 player agent not found!
# https://www.transfermarkt.com/ledian-memushaj/profil/spieler/139634 player agent not found!
# https://www.transfermarkt.com/alberto-aquilani/profil/spieler/5957 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-bruno/profil/spieler/77910 player agent not found!
# https://www.transfermarkt.com/alexandru-mitrita/profil/spieler/209649 player agent not found!
# https://www.transfermarkt.com/ferdinando-del-sole/profil/spieler/355479 player agent not found!
# https://www.transfermarkt.com/alberto-gilardino/profil/spieler/5878 duplicate id found and skiped
# https://www.transfermarkt.com/marco-acatullo/profil/spieler/395539 player agent not found!
# https://www.transfermarkt.com/stefano-sorrentino/profil/spieler/21891 player agent not found!
# https://www.transfermarkt.com/walter-bressan/profil/spieler/38582 player agent not found!
# https://www.transfermarkt.com/filippo-pavoni/profil/spieler/394348 player agent not found!
# https://www.transfermarkt.com/alessandro-gamberini/profil/spieler/16868 player agent not found!
# https://www.transfermarkt.com/massimo-gobbi/profil/spieler/28020 player agent not found!
# https://www.transfermarkt.com/fabrizio-cacciatore/profil/spieler/85605 player agent not found!
# https://www.transfermarkt.com/gennaro-sardo/profil/spieler/21770 player agent not found!
# https://www.transfermarkt.com/jonathan-de-guzman/profil/spieler/31067 duplicate id found and skiped
# https://www.transfermarkt.com/lucas-castro/profil/spieler/105892 player agent not found!
# https://www.transfermarkt.com/victor/profil/spieler/190206 player agent not found!
# https://www.transfermarkt.com/vittorio-parigini/profil/spieler/238981 player agent not found!
# https://www.transfermarkt.com/serge-gakpe/profil/spieler/36293 duplicate id found and skiped
# https://www.transfermarkt.com/antonio-floro-flores/profil/spieler/16893 player agent not found!
# https://www.transfermarkt.com/lamin-jallow/profil/spieler/337310 player agent not found!
# https://www.transfermarkt.com/andrea-isufaj/profil/spieler/463356 player agent not found!
# https://www.transfermarkt.com/ngissah-bismark/profil/spieler/340639 player agent not found!
# https://www.transfermarkt.com/samuele-guddo/profil/spieler/375299 player agent not found!
# https://www.transfermarkt.com/sebastian-breza/profil/spieler/459842 player agent not found!
# https://www.transfermarkt.com/slobodan-rajkovi%C4%87/profil/spieler/35934 player agent not found!
# https://www.transfermarkt.com/simone-giuliano/profil/spieler/291408 player agent not found!
# https://www.transfermarkt.com/andrea-punzi/profil/spieler/336956 player agent not found!
# https://www.transfermarkt.com/roberto-vitiello/profil/spieler/22217 player agent not found!
# https://www.transfermarkt.com/ouasim-bouy/profil/spieler/126412 player agent not found!
# https://www.transfermarkt.com/alessandro-gazzi/profil/spieler/28827 player agent not found!
# https://www.transfermarkt.com/marco-toscano/profil/spieler/336959 player agent not found!
# https://www.transfermarkt.com/oscar-hiljemark/profil/spieler/158810 duplicate id found and skiped
# https://www.transfermarkt.com/ivaylo-chochev/profil/spieler/252767 player agent not found!
# https://www.transfermarkt.com/francesco-bonfiglio/profil/spieler/297064 player agent not found!
# https://www.transfermarkt.com/simone-lo-faso/profil/spieler/349719 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/206542/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/claiton/profil/spieler/139169 player agent not found!
# https://www.transfermarkt.com/giuseppe-cuomo/profil/spieler/365565 player agent not found!
# https://www.transfermarkt.com/luca-bruno/profil/spieler/285091 player agent not found!
# https://www.transfermarkt.com/djamel-mesbah/profil/spieler/17735 duplicate id found and skiped
# https://www.transfermarkt.com/aleandro-rosi/profil/spieler/34239 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-crisetig/profil/spieler/110928 duplicate id found and skiped
# https://www.transfermarkt.com/cazim-suljic/profil/spieler/348431 player agent not found!
# https://www.transfermarkt.com/nicolo-fazzi/profil/spieler/197744 player agent not found!
# https://www.transfermarkt.com/giuseppe-zampano/profil/spieler/199597 player agent not found!
# https://www.transfermarkt.com/andrej-kotnik/profil/spieler/382007 player agent not found!
# https://www.transfermarkt.com/raffaele-palladino/profil/spieler/28855 duplicate id found and skiped
# https://www.transfermarkt.com/giuseppe-borello/profil/spieler/373379 player agent not found!
# https://www.transfermarkt.com/diego-falcinelli/profil/spieler/119115 duplicate id found and skiped
# https://www.transfermarkt.com/marcello-trotta/profil/spieler/129505 duplicate id found and skiped
# leagues:   0%|          | 0/1 [00:00<?, ?it/s]
# teams:   0%|          | 0/20 [00:00<?, ?it/s]
# https://www.transfermarkt.com/wojciech-szczesny/profil/spieler/44058 duplicate id found and skiped
# https://www.transfermarkt.com/emil-audero/profil/spieler/256339 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-perin/profil/spieler/110923 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-del-favero/profil/spieler/265079 duplicate id found and skiped
# https://www.transfermarkt.com/leonardo-bonucci/profil/spieler/39983 duplicate id found and skiped
# https://www.transfermarkt.com/daniele-rugani/profil/spieler/162959 duplicate id found and skiped
# https://www.transfermarkt.com/medhi-benatia/profil/spieler/45124 duplicate id found and skiped
# https://www.transfermarkt.com/giorgio-chiellini/profil/spieler/29260 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-barzagli/profil/spieler/7109 duplicate id found and skiped
# https://www.transfermarkt.com/luca-marrone/profil/spieler/124769 duplicate id found and skiped
# https://www.transfermarkt.com/luca-coccolo/profil/spieler/344655 duplicate id found and skiped
# https://www.transfermarkt.com/alex-sandro/profil/spieler/79960 duplicate id found and skiped
# https://www.transfermarkt.com/leonardo-spinazzola/profil/spieler/118689 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-de-sciglio/profil/spieler/88682 duplicate id found and skiped
# https://www.transfermarkt.com/francesco-pezziardi/profil/spieler/455209 player agent not found!
# https://www.transfermarkt.com/miralem-pjanic/profil/spieler/44162 duplicate id found and skiped
# https://www.transfermarkt.com/stefano-sturaro/profil/spieler/167859 duplicate id found and skiped
# https://www.transfermarkt.com/sami-khedira/profil/spieler/29401 duplicate id found and skiped
# https://www.transfermarkt.com/matheus-pereira/profil/spieler/323934 duplicate id found and skiped
# https://www.transfermarkt.com/grigoris-kastanos/profil/spieler/298635 duplicate id found and skiped
# https://www.transfermarkt.com/simone-muratore/profil/spieler/297648 duplicate id found and skiped
# https://www.transfermarkt.com/juan-cuadrado/profil/spieler/91970 duplicate id found and skiped
# https://www.transfermarkt.com/marko-pjaca/profil/spieler/205940 duplicate id found and skiped
# https://www.transfermarkt.com/federico-bernardeschi/profil/spieler/197300 duplicate id found and skiped
# https://www.transfermarkt.com/paulo-dybala/profil/spieler/206050 duplicate id found and skiped
# https://www.transfermarkt.com/moise-kean/profil/spieler/364135 duplicate id found and skiped
# https://www.transfermarkt.com/gonzalo-higuain/profil/spieler/39153 duplicate id found and skiped
# https://www.transfermarkt.com/mario-mandzukic/profil/spieler/34572 duplicate id found and skiped
# https://www.transfermarkt.com/alberto-cerri/profil/spieler/197751 duplicate id found and skiped
# https://www.transfermarkt.com/davide-cais/profil/spieler/176463 player agent not found!
# https://www.transfermarkt.com/luigi-sepe/profil/spieler/99254 duplicate id found and skiped
# https://www.transfermarkt.com/orestis-karnezis/profil/spieler/16408 duplicate id found and skiped
# https://www.transfermarkt.com/davide-marfella/profil/spieler/417414 player agent not found!
# https://www.transfermarkt.com/alessandro-dandrea/profil/spieler/392331 player agent not found!
# https://www.transfermarkt.com/antonio-pio-daniele/profil/spieler/618502 player agent not found!
# https://www.transfermarkt.com/kalidou-koulibaly/profil/spieler/93128 duplicate id found and skiped
# https://www.transfermarkt.com/nikola-maksimovic/profil/spieler/124715 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-tonelli/profil/spieler/111347 duplicate id found and skiped
# https://www.transfermarkt.com/raul-albiol/profil/spieler/15452 duplicate id found and skiped
# https://www.transfermarkt.com/vlad-chiriches/profil/spieler/123261 duplicate id found and skiped
# https://www.transfermarkt.com/sebastiano-luperto/profil/spieler/278531 duplicate id found and skiped
# https://www.transfermarkt.com/igor-lasicki/profil/spieler/225874 duplicate id found and skiped
# https://www.transfermarkt.com/faouzi-ghoulam/profil/spieler/126656 duplicate id found and skiped
# https://www.transfermarkt.com/mario-rui/profil/spieler/87884 duplicate id found and skiped
# https://www.transfermarkt.com/luigi-dignazio/profil/spieler/355051 player agent not found!
# https://www.transfermarkt.com/elseid-hysaj/profil/spieler/200056 duplicate id found and skiped
# https://www.transfermarkt.com/allan/profil/spieler/126422 duplicate id found and skiped
# https://www.transfermarkt.com/amadou-diawara/profil/spieler/355501 duplicate id found and skiped
# https://www.transfermarkt.com/umberto-otranto/profil/spieler/370821 player agent not found!
# https://www.transfermarkt.com/piotr-zielinski/profil/spieler/181136 duplicate id found and skiped
# https://www.transfermarkt.com/marek-hamsik/profil/spieler/38593 duplicate id found and skiped
# https://www.transfermarkt.com/alberto-grassi/profil/spieler/197473 duplicate id found and skiped
# https://www.transfermarkt.com/marko-rog/profil/spieler/317482 duplicate id found and skiped
# https://www.transfermarkt.com/zinedine-machach/profil/spieler/146143 player height not found!
# https://www.transfermarkt.com/antonio-romano/profil/spieler/238989 player agent not found!
# https://www.transfermarkt.com/simone-verdi/profil/spieler/130360 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-insigne/profil/spieler/133964 duplicate id found and skiped
# https://www.transfermarkt.com/leandrinho/profil/spieler/351898 duplicate id found and skiped
# https://www.transfermarkt.com/alessio-zerbin/profil/spieler/433584 duplicate id found and skiped
# https://www.transfermarkt.com/jose-callejon/profil/spieler/61253 duplicate id found and skiped
# https://www.transfermarkt.com/roberto-insigne/profil/spieler/200174 duplicate id found and skiped
# https://www.transfermarkt.com/dries-mertens/profil/spieler/56416 duplicate id found and skiped
# https://www.transfermarkt.com/arkadiusz-milik/profil/spieler/191891 duplicate id found and skiped
# https://www.transfermarkt.com/roberto-inglese/profil/spieler/159337 duplicate id found and skiped
# https://www.transfermarkt.com/ionut-radu/profil/spieler/303657 duplicate id found and skiped
# https://www.transfermarkt.com/samir-handanovic/profil/spieler/28021 duplicate id found and skiped
# https://www.transfermarkt.com/raffaele-di-gennaro/profil/spieler/70580 player agent not found!
# https://www.transfermarkt.com/daniele-padelli/profil/spieler/27807 duplicate id found and skiped
# https://www.transfermarkt.com/michele-di-gregorio/profil/spieler/301238 duplicate id found and skiped
# https://www.transfermarkt.com/tommaso-berni/profil/spieler/21752 duplicate id found and skiped
# https://www.transfermarkt.com/milan-skriniar/profil/spieler/204069 duplicate id found and skiped
# https://www.transfermarkt.com/stefan-de-vrij/profil/spieler/111196 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-bastoni/profil/spieler/315853 duplicate id found and skiped
# https://www.transfermarkt.com/danilo-dambrosio/profil/spieler/55769 duplicate id found and skiped
# https://www.transfermarkt.com/zinho-vanheusden/profil/spieler/338672 duplicate id found and skiped
# https://www.transfermarkt.com/andreaw-gravillon/profil/spieler/395083 duplicate id found and skiped
# https://www.transfermarkt.com/miranda/profil/spieler/33357 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-ranocchia/profil/spieler/44327 duplicate id found and skiped
# https://www.transfermarkt.com/cristian-ansaldi/profil/spieler/55854 duplicate id found and skiped
# https://www.transfermarkt.com/federico-dimarco/profil/spieler/198116 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-bandini/profil/spieler/199902 player agent not found!
# https://www.transfermarkt.com/marcelo-brozovic/profil/spieler/156617 duplicate id found and skiped
# https://www.transfermarkt.com/radja-nainggolan/profil/spieler/41982 duplicate id found and skiped
# https://www.transfermarkt.com/matias-vecino/profil/spieler/143812 duplicate id found and skiped
# https://www.transfermarkt.com/joao-mario/profil/spieler/149729 duplicate id found and skiped
# https://www.transfermarkt.com/roberto-gagliardini/profil/spieler/197471 duplicate id found and skiped
# https://www.transfermarkt.com/borja-valero/profil/spieler/40372 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-romano/profil/spieler/136130 player agent not found!
# https://www.transfermarkt.com/tommaso-brignoli/profil/spieler/417818 player agent not found!
# https://www.transfermarkt.com/antonio-candreva/profil/spieler/25488 duplicate id found and skiped
# https://www.transfermarkt.com/ivan-perisic/profil/spieler/42460 duplicate id found and skiped
# https://www.transfermarkt.com/kwadwo-asamoah/profil/spieler/63531 duplicate id found and skiped
# https://www.transfermarkt.com/xian-emmers/profil/spieler/365449 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-politano/profil/spieler/165895 duplicate id found and skiped
# https://www.transfermarkt.com/axel-bakayoko/profil/spieler/354898 duplicate id found and skiped
# https://www.transfermarkt.com/rigoberto-rivas/profil/spieler/451353 duplicate id found and skiped
# https://www.transfermarkt.com/mauro-icardi/profil/spieler/68863 duplicate id found and skiped
# https://www.transfermarkt.com/keita-balde/profil/spieler/238752 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-pinamonti/profil/spieler/315865 duplicate id found and skiped
# https://www.transfermarkt.com/rey-manaj/profil/spieler/308278 duplicate id found and skiped
# https://www.transfermarkt.com/gianluigi-donnarumma/profil/spieler/315858 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-plizzari/profil/spieler/357991 duplicate id found and skiped
# https://www.transfermarkt.com/pepe-reina/profil/spieler/7825 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-soncin/profil/spieler/401161 player agent not found!
# https://www.transfermarkt.com/alessio-romagnoli/profil/spieler/197747 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-caldara/profil/spieler/197470 duplicate id found and skiped
# https://www.transfermarkt.com/gustavo-gomez/profil/spieler/215390 duplicate id found and skiped
# https://www.transfermarkt.com/cristian-zapata/profil/spieler/34344 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-gabbia/profil/spieler/323167 duplicate id found and skiped
# https://www.transfermarkt.com/stefan-simic/profil/spieler/198613 player agent not found!
# https://www.transfermarkt.com/diego-laxalt/profil/spieler/230552 duplicate id found and skiped
# https://www.transfermarkt.com/ivan-strinic/profil/spieler/39799 duplicate id found and skiped
# https://www.transfermarkt.com/davide-calabria/profil/spieler/262523 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-conti/profil/spieler/111227 duplicate id found and skiped
# https://www.transfermarkt.com/ignazio-abate/profil/spieler/16631 duplicate id found and skiped
# https://www.transfermarkt.com/manuel-locatelli/profil/spieler/265088 duplicate id found and skiped
# https://www.transfermarkt.com/lucas-biglia/profil/spieler/26721 duplicate id found and skiped
# https://www.transfermarkt.com/riccardo-montolivo/profil/spieler/19446 duplicate id found and skiped
# https://www.transfermarkt.com/franck-kessie/profil/spieler/294808 duplicate id found and skiped
# https://www.transfermarkt.com/giacomo-bonaventura/profil/spieler/57280 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-bertolacci/profil/spieler/99227 duplicate id found and skiped
# https://www.transfermarkt.com/jose-mauri/profil/spieler/240958 duplicate id found and skiped
# https://www.transfermarkt.com/alen-halilovic/profil/spieler/226074 player agent not found!
# https://www.transfermarkt.com/suso/profil/spieler/111961 duplicate id found and skiped
# https://www.transfermarkt.com/gonzalo-higuain/profil/spieler/39153 duplicate id found and skiped
# https://www.transfermarkt.com/patrick-cutrone/profil/spieler/265078 duplicate id found and skiped
# https://www.transfermarkt.com/antonio-mirante/profil/spieler/22141 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-crisanto/profil/spieler/340430 duplicate id found and skiped
# https://www.transfermarkt.com/stefano-greco/profil/spieler/319177 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-romagnoli/profil/spieler/391406 duplicate id found and skiped
# https://www.transfermarkt.com/konstantinos-manolas/profil/spieler/104752 duplicate id found and skiped
# https://www.transfermarkt.com/juan-jesus/profil/spieler/121985 duplicate id found and skiped
# https://www.transfermarkt.com/federico-fazio/profil/spieler/45314 duplicate id found and skiped
# https://www.transfermarkt.com/matias-nani/profil/spieler/486597 player agent not found!
# https://www.transfermarkt.com/riccardo-cargnelutti/profil/spieler/392444 player height not found!
# https://www.transfermarkt.com/luca-pellegrini/profil/spieler/346567 duplicate id found and skiped
# https://www.transfermarkt.com/davide-santon/profil/spieler/84344 duplicate id found and skiped
# https://www.transfermarkt.com/moustapha-seck/profil/spieler/268179 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-valeau/profil/spieler/357178 player agent not found!
# https://www.transfermarkt.com/alessandro-florenzi/profil/spieler/130365 duplicate id found and skiped
# https://www.transfermarkt.com/bryan-cristante/profil/spieler/199248 duplicate id found and skiped
# https://www.transfermarkt.com/daniele-de-rossi/profil/spieler/5947 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-marcucci/profil/spieler/319180 player agent not found!
# https://www.transfermarkt.com/kevin-strootman/profil/spieler/68864 duplicate id found and skiped
# https://www.transfermarkt.com/gerson/profil/spieler/341705 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-bordin/profil/spieler/315844 duplicate id found and skiped
# https://www.transfermarkt.com/emanuele-spinozzi/profil/spieler/340447 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-pellegrini/profil/spieler/286297 duplicate id found and skiped
# https://www.transfermarkt.com/lorenzo-di-livio/profil/spieler/315568 duplicate id found and skiped
# https://www.transfermarkt.com/stephan-el-shaarawy/profil/spieler/94529 duplicate id found and skiped
# https://www.transfermarkt.com/diego-perotti/profil/spieler/54984 duplicate id found and skiped
# https://www.transfermarkt.com/keba-coly/profil/spieler/415454 duplicate id found and skiped
# https://www.transfermarkt.com/mirko-antonucci/profil/spieler/315852 duplicate id found and skiped
# https://www.transfermarkt.com/patrik-schick/profil/spieler/242086 duplicate id found and skiped
# https://www.transfermarkt.com/edin-dzeko/profil/spieler/28396 duplicate id found and skiped
# https://www.transfermarkt.com/gregoire-defrel/profil/spieler/163222 duplicate id found and skiped
# https://www.transfermarkt.com/umar-sadiq/profil/spieler/337715 duplicate id found and skiped
# https://www.transfermarkt.com/edoardo-soleri/profil/spieler/321065 duplicate id found and skiped
# https://www.transfermarkt.com/pierluigi-gollini/profil/spieler/244192 duplicate id found and skiped
# https://www.transfermarkt.com/marco-sportiello/profil/spieler/199976 duplicate id found and skiped
# https://www.transfermarkt.com/etrit-berisha/profil/spieler/77825 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-santopadre/profil/spieler/395102 player agent not found!
# https://www.transfermarkt.com/francesco-rossi/profil/spieler/126634 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-turrin/profil/spieler/338297 player agent not found!
# https://www.transfermarkt.com/stefano-mazzini/profil/spieler/346528 duplicate id found and skiped
# https://www.transfermarkt.com/roberto-taliento/profil/spieler/392951 duplicate id found and skiped
# https://www.transfermarkt.com/rafael-toloi/profil/spieler/72441 duplicate id found and skiped
# https://www.transfermarkt.com/jose-luis-palomino/profil/spieler/125020 player agent not found!
# https://www.transfermarkt.com/berat-djimsiti/profil/spieler/165513 duplicate id found and skiped
# https://www.transfermarkt.com/marco-varnier/profil/spieler/362981 player agent not found!
# https://www.transfermarkt.com/andrea-masiello/profil/spieler/34198 duplicate id found and skiped
# https://www.transfermarkt.com/emanuele-suagher/profil/spieler/163600 duplicate id found and skiped
# https://www.transfermarkt.com/anton-kresic/profil/spieler/226080 player agent not found!
# https://www.transfermarkt.com/andrea-boffelli/profil/spieler/337383 player height not found!
# https://www.transfermarkt.com/andrea-boffelli/profil/spieler/337383 player agent not found!
# https://www.transfermarkt.com/riccardo-gatti/profil/spieler/337385 duplicate id found and skiped
# https://www.transfermarkt.com/stefano-marchetti/profil/spieler/392586 player agent not found!
# https://www.transfermarkt.com/matteo-salvi/profil/spieler/458096 player agent not found!
# https://www.transfermarkt.com/caleb-okoli/profil/spieler/461833 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/268178/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/ali-adnan/profil/spieler/261611 duplicate id found and skiped
# https://www.transfermarkt.com/fabio-eguelfi/profil/spieler/200192 player agent not found!
# https://www.transfermarkt.com/lorenzo-migliorelli/profil/spieler/352663 player agent not found!
# https://www.transfermarkt.com/enrico-zanoni/profil/spieler/392958 player agent not found!
# https://www.transfermarkt.com/hans-hateboer/profil/spieler/275303 duplicate id found and skiped
# https://www.transfermarkt.com/federico-mattiello/profil/spieler/200194 duplicate id found and skiped
# https://www.transfermarkt.com/christian-mora/profil/spieler/301239 player agent not found!
# ...
# https://www.transfermarkt.com/sebastian-cristoforo/profil/spieler/188157 duplicate id found and skiped
# https://www.transfermarkt.com/nicky-beloko/profil/spieler/382774 player agent not found!
# https://www.transfermarkt.com/luzayadio-bangu/profil/spieler/247376 player agent not found!
# https://www.transfermarkt.com/amidu-salifu/profil/spieler/146596 duplicate id found and skiped
# https://www.transfermarkt.com/riccardo-saponara/profil/spieler/88909 duplicate id found and skiped
# https://www.transfermarkt.com/valentin-eysseric/profil/spieler/126687 player agent not found!
# https://www.transfermarkt.com/federico-chiesa/profil/spieler/341092 duplicate id found and skiped
# https://www.transfermarkt.com/marko-pjaca/profil/spieler/205940 duplicate id found and skiped
# https://www.transfermarkt.com/jaime-baez/profil/spieler/238654 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-trovato/profil/spieler/297651 player agent not found!
# https://www.transfermarkt.com/cyril-thereau/profil/spieler/29316 duplicate id found and skiped
# https://www.transfermarkt.com/giovanni-simeone/profil/spieler/282388 duplicate id found and skiped
# https://www.transfermarkt.com/luis-muriel/profil/spieler/119228 duplicate id found and skiped
# https://www.transfermarkt.com/martin-graiciar/profil/spieler/319176 player agent not found!
# https://www.transfermarkt.com/thomas-strakosha/profil/spieler/222209 duplicate id found and skiped
# https://www.transfermarkt.com/ivan-vargic/profil/spieler/34553 duplicate id found and skiped
# https://www.transfermarkt.com/marius-adamonis/profil/spieler/300137 duplicate id found and skiped
# https://www.transfermarkt.com/alessio-furlanetto/profil/spieler/538079 player foot not found!
# https://www.transfermarkt.com/alessio-furlanetto/profil/spieler/538079 player agent not found!
# https://www.transfermarkt.com/francesco-acerbi/profil/spieler/131075 duplicate id found and skiped
# https://www.transfermarkt.com/wallace/profil/spieler/225335 duplicate id found and skiped
# https://www.transfermarkt.com/bastos/profil/spieler/195810 duplicate id found and skiped
# https://www.transfermarkt.com/patric/profil/spieler/126729 duplicate id found and skiped
# https://www.transfermarkt.com/martin-caceres/profil/spieler/54935 duplicate id found and skiped
# https://www.transfermarkt.com/jordan-lukaku/profil/spieler/140804 duplicate id found and skiped
# https://www.transfermarkt.com/stefan-radu/profil/spieler/44420 duplicate id found and skiped
# https://www.transfermarkt.com/dusan-basta/profil/spieler/19694 duplicate id found and skiped
# https://www.transfermarkt.com/giorgio-spizzichino/profil/spieler/391933 duplicate id found and skiped
# https://www.transfermarkt.com/mauro-zitelli/profil/spieler/392049 player agent not found!
# https://www.transfermarkt.com/milan-badelj/profil/spieler/40633 duplicate id found and skiped
# https://www.transfermarkt.com/danilo-cataldi/profil/spieler/199733 duplicate id found and skiped
# https://www.transfermarkt.com/joseph-minala/profil/spieler/289087 duplicate id found and skiped
# https://www.transfermarkt.com/alessio-bianchi/profil/spieler/364134 player height not found!
# https://www.transfermarkt.com/alessio-bianchi/profil/spieler/364134 player foot not found!
# https://www.transfermarkt.com/alessio-bianchi/profil/spieler/364134 player agent not found!
# https://www.transfermarkt.com/sergej-milinkovic-savic/profil/spieler/266302 duplicate id found and skiped
# https://www.transfermarkt.com/luis-alberto/profil/spieler/128220 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-murgia/profil/spieler/289061 duplicate id found and skiped
# https://www.transfermarkt.com/marco-parolo/profil/spieler/84545 duplicate id found and skiped
# https://www.transfermarkt.com/edoardo-rezzi/profil/spieler/394301 player height not found!
# https://www.transfermarkt.com/edoardo-rezzi/profil/spieler/394301 player agent not found!
# https://www.transfermarkt.com/abukar-mohamed/profil/spieler/363714 duplicate id found and skiped
# https://www.transfermarkt.com/senad-lulic/profil/spieler/61449 duplicate id found and skiped
# https://www.transfermarkt.com/davide-di-gennaro/profil/spieler/52136 duplicate id found and skiped
# https://www.transfermarkt.com/luan-capanni/profil/spieler/601877 player agent not found!
# https://www.transfermarkt.com/ricardo-kishna/profil/spieler/159026 duplicate id found and skiped
# https://www.transfermarkt.com/cristiano-lombardi/profil/spieler/240349 duplicate id found and skiped
# https://www.transfermarkt.com/daniel-bezziccheri/profil/spieler/337810 player height not found!
# https://www.transfermarkt.com/daniel-bezziccheri/profil/spieler/337810 player foot not found!
# https://www.transfermarkt.com/alessandro-cerbara/profil/spieler/459095 player agent not found!
# https://www.transfermarkt.com/ciro-immobile/profil/spieler/105521 duplicate id found and skiped
# https://www.transfermarkt.com/simone-palombi/profil/spieler/289065 player agent not found!
# https://www.transfermarkt.com/alessandro-rossi/profil/spieler/339782 duplicate id found and skiped
# https://www.transfermarkt.com/mamadou-tounkara/profil/spieler/242965 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-consigli/profil/spieler/35865 duplicate id found and skiped
# https://www.transfermarkt.com/giacomo-satalino/profil/spieler/323255 duplicate id found and skiped
# https://www.transfermarkt.com/gianluca-pegolo/profil/spieler/21872 duplicate id found and skiped
# https://www.transfermarkt.com/gian-marco-ferrari/profil/spieler/277167 duplicate id found and skiped
# https://www.transfermarkt.com/timo-letschert/profil/spieler/231378 duplicate id found and skiped
# https://www.transfermarkt.com/edoardo-goldaniga/profil/spieler/242940 duplicate id found and skiped
# https://www.transfermarkt.com/luca-ravanelli/profil/spieler/312341 duplicate id found and skiped
# https://www.transfermarkt.com/leonardo-fontanesi/profil/spieler/287638 duplicate id found and skiped
# https://www.transfermarkt.com/martin-erlic/profil/spieler/357003 duplicate id found and skiped
# https://www.transfermarkt.com/stefano-ferraresi/profil/spieler/423608 player agent not found!
# https://www.transfermarkt.com/rogerio/profil/spieler/401527 duplicate id found and skiped
# https://www.transfermarkt.com/cristian-dellorco/profil/spieler/240244 duplicate id found and skiped
# https://www.transfermarkt.com/riccardo-marchizza/profil/spieler/297645 duplicate id found and skiped
# https://www.transfermarkt.com/federico-peluso/profil/spieler/21763 duplicate id found and skiped
# https://www.transfermarkt.com/pol-lirola/profil/spieler/298975 duplicate id found and skiped
# https://www.transfermarkt.com/claud-adjapong/profil/spieler/337716 duplicate id found and skiped
# https://www.transfermarkt.com/leonardo-sernicola/profil/spieler/340707 player agent not found!
# https://www.transfermarkt.com/manuel-locatelli/profil/spieler/265088 duplicate id found and skiped
# https://www.transfermarkt.com/luca-mazzitelli/profil/spieler/226025 duplicate id found and skiped
# https://www.transfermarkt.com/francesco-magnanelli/profil/spieler/7093 duplicate id found and skiped
# https://www.transfermarkt.com/stefano-sensi/profil/spieler/216179 duplicate id found and skiped
# https://www.transfermarkt.com/alfred-duncan/profil/spieler/184894 duplicate id found and skiped
# https://www.transfermarkt.com/davide-frattesi/profil/spieler/394300 duplicate id found and skiped
# https://www.transfermarkt.com/simone-missiroli/profil/spieler/35747 duplicate id found and skiped
# https://www.transfermarkt.com/giovanni-sbrissa/profil/spieler/284636 duplicate id found and skiped
# https://www.transfermarkt.com/marius-marin/profil/spieler/379163 duplicate id found and skiped
# https://www.transfermarkt.com/giacomo-zecca/profil/spieler/320456 duplicate id found and skiped
# https://www.transfermarkt.com/filip-djuricic/profil/spieler/94307 duplicate id found and skiped
# https://www.transfermarkt.com/federico-di-francesco/profil/spieler/38607 duplicate id found and skiped
# https://www.transfermarkt.com/antonino-ragusa/profil/spieler/102470 duplicate id found and skiped
# https://www.transfermarkt.com/nicholas-pierini/profil/spieler/372720 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-politano/profil/spieler/165895 duplicate id found and skiped
# https://www.transfermarkt.com/domenico-berardi/profil/spieler/177843 duplicate id found and skiped
# https://www.transfermarkt.com/federico-ricci/profil/spieler/198086 duplicate id found and skiped
# https://www.transfermarkt.com/khouma-babacar/profil/spieler/124902 duplicate id found and skiped
# https://www.transfermarkt.com/marcello-trotta/profil/spieler/129505 duplicate id found and skiped
# https://www.transfermarkt.com/gianluca-scamacca/profil/spieler/315867 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-matri/profil/spieler/40660 duplicate id found and skiped
# https://www.transfermarkt.com/salvatore-sirigu/profil/spieler/25508 player agent not found!
# https://www.transfermarkt.com/andrea-zaccagno/profil/spieler/291314 player agent not found!
# https://www.transfermarkt.com/salvador-ichazo/profil/spieler/131098 duplicate id found and skiped
# https://www.transfermarkt.com/tommaso-cucchietti/profil/spieler/315788 duplicate id found and skiped
# https://www.transfermarkt.com/armando-izzo/profil/spieler/32113 duplicate id found and skiped
# https://www.transfermarkt.com/carlao/profil/spieler/52893 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-buongiorno/profil/spieler/386446 duplicate id found and skiped
# https://www.transfermarkt.com/emiliano-moretti/profil/spieler/5755 duplicate id found and skiped
# https://www.transfermarkt.com/edoardo-bianchi/profil/spieler/346566 player agent not found!
# https://www.transfermarkt.com/cristian-ansaldi/profil/spieler/55854 duplicate id found and skiped
# https://www.transfermarkt.com/danilo-avelar/profil/spieler/140748 duplicate id found and skiped
# https://www.transfermarkt.com/federico-giraudo/profil/spieler/349715 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-sana/profil/spieler/397824 duplicate id found and skiped
# https://www.transfermarkt.com/sulaiman-oyewale/profil/spieler/474811 player height not found!
# https://www.transfermarkt.com/emanuele-valerio/profil/spieler/386449 player height not found!
# https://www.transfermarkt.com/lorenzo-de-silvestri/profil/spieler/33571 duplicate id found and skiped
# https://www.transfermarkt.com/filippo-gilli/profil/spieler/463795 player agent not found!
# https://www.transfermarkt.com/tomas-rincon/profil/spieler/75942 duplicate id found and skiped
# https://www.transfermarkt.com/samuel-gustafson/profil/spieler/255473 duplicate id found and skiped
# https://www.transfermarkt.com/mirko-valdifiori/profil/spieler/84903 duplicate id found and skiped
# https://www.transfermarkt.com/daniele-baselli/profil/spieler/134883 duplicate id found and skiped
# https://www.transfermarkt.com/sasa-lukic/profil/spieler/245056 duplicate id found and skiped
# https://www.transfermarkt.com/matteo-rossetti/profil/spieler/440878 duplicate id found and skiped
# https://www.transfermarkt.com/nathan-buaka/profil/spieler/428257 player agent not found!
# https://www.transfermarkt.com/adem-ljaji%C4%87/profil/spieler/69374 duplicate id found and skiped
# https://www.transfermarkt.com/mattia-aramu/profil/spieler/200188 duplicate id found and skiped
# https://www.transfermarkt.com/vincenzo-millico/profil/spieler/390159 player agent not found!
# https://www.transfermarkt.com/iago-falque/profil/spieler/59340 duplicate id found and skiped
# https://www.transfermarkt.com/vittorio-parigini/profil/spieler/238981 duplicate id found and skiped
# https://www.transfermarkt.com/filippo-berardi/profil/spieler/355611 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-belotti/profil/spieler/167727 duplicate id found and skiped
# https://www.transfermarkt.com/mbaye-niang/profil/spieler/157501 duplicate id found and skiped
# https://www.transfermarkt.com/simone-zaza/profil/spieler/96828 duplicate id found and skiped
# https://www.transfermarkt.com/lucas-boye/profil/spieler/334222 duplicate id found and skiped
# https://www.transfermarkt.com/manuel-de-luca/profil/spieler/375816 duplicate id found and skiped
# https://www.transfermarkt.com/emil-audero/profil/spieler/256339 duplicate id found and skiped
# https://www.transfermarkt.com/rafael-cabral/profil/spieler/103916 duplicate id found and skiped
# https://www.transfermarkt.com/wladimiro-falcone/profil/spieler/238537 duplicate id found and skiped
# https://www.transfermarkt.com/andrea-tozzo/profil/spieler/57657 duplicate id found and skiped
# https://www.transfermarkt.com/titas-krapikas/profil/spieler/353609 duplicate id found and skiped
# https://www.transfermarkt.com/giacomo-piccardo/profil/spieler/393604 player agent not found!
# https://www.transfermarkt.com/lorenzo-tonelli/profil/spieler/111347 duplicate id found and skiped
# https://www.transfermarkt.com/alex-ferrari/profil/spieler/197491 duplicate id found and skiped
# https://www.transfermarkt.com/lorenco-simic/profil/spieler/226093 duplicate id found and skiped
# https://www.transfermarkt.com/filippo-oliana/profil/spieler/393607 player agent not found!
# https://www.transfermarkt.com/nicola-murru/profil/spieler/171399 duplicate id found and skiped
# https://www.transfermarkt.com/vasco-regini/profil/spieler/72274 duplicate id found and skiped
# https://www.transfermarkt.com/bartosz-bereszynski/profil/spieler/144143 duplicate id found and skiped
# https://www.transfermarkt.com/michal-tomic/profil/spieler/344321 duplicate id found and skiped
# https://www.transfermarkt.com/carlo-romei/profil/spieler/398058 player agent not found!
# https://www.transfermarkt.com/david-ivan/profil/spieler/168416 duplicate id found and skiped
# https://www.transfermarkt.com/alessandro-gabbani/profil/spieler/397869 player agent not found!
# https://www.transfermarkt.com/dennis-praet/profil/spieler/129588 duplicate id found and skiped
# https://www.transfermarkt.com/karol-linetty/profil/spieler/225873 duplicate id found and skiped
# https://www.transfermarkt.com/jacopo-sala/profil/spieler/96806 duplicate id found and skiped
# https://www.transfermarkt.com/edgar-barreto/profil/spieler/16120 duplicate id found and skiped
# https://www.transfermarkt.com/leonardo-capezzi/profil/spieler/84442 duplicate id found and skiped
# https://www.transfermarkt.com/denis-baumgartner/profil/spieler/324993 duplicate id found and skiped
# https://www.transfermarkt.com/jakub-jankto/profil/spieler/319160 duplicate id found and skiped
# https://www.transfermarkt.com/riccardo-saponara/profil/spieler/88909 duplicate id found and skiped
# https://www.transfermarkt.com/valerio-verre/profil/spieler/162961 duplicate id found and skiped
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/461600/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/gianluca-caprari/profil/spieler/146752 duplicate id found and skiped
# https://www.transfermarkt.com/manolo-gabbiadini/profil/spieler/112343 duplicate id found and skiped
# https://www.transfermarkt.com/gregoire-defrel/profil/spieler/163222 duplicate id found and skiped
# https://www.transfermarkt.com/fabio-quagliarella/profil/spieler/22328 duplicate id found and skiped
# https://www.transfermarkt.com/giacomo-vrioni/profil/spieler/363178 duplicate id found and skiped
# https://www.transfermarkt.com/marco-sau/profil/spieler/55801 duplicate id found and skiped
# https://www.transfermarkt.com/ibourahima-balde/profil/spieler/398061 duplicate id found and skiped
# https://www.transfermarkt.com/alex-meret/profil/spieler/240414 duplicate id found and skiped
# https://www.transfermarkt.com/simone-scuffet/profil/spieler/238993 duplicate id found and skiped
# https://www.transfermarkt.com/orestis-karnezis/profil/spieler/16408 duplicate id found and skiped
# https://www.transfermarkt.com/samuele-perisan/profil/spieler/301240 duplicate id found and skiped
# https://www.transfermarkt.com/samir-caetano/profil/spieler/255744 duplicate id found and skiped

# %% [markdown]
# # Test area

# %%
def test (id): # id is for returning an eeror 
  detail_page = detail_page_request(id)
  detail_link_format = 'https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/{}/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1'
  # find table in html
  try:
    table = detail_page.find('table', class_='items')
  except:
    print(detail_link_format.format(id)+" detail table not found!")

  # find column names
  column_values=['player_id']
  try:
    header = detail_page.find('table', class_='items').find('thead').find('tr').find_all('th')
    for th in header:
      if th['id'] == 'yw1_c2':
        continue
      try:
        column_values.append(th.find('a').find('span')['title'])
      except:
        column_values.append(th.text)
    #print(column_values)
  except:
    print(detail_link_format.format(id)+" table column_value found!")

  # creat data frame 
  detail_table= pd.DataFrame(columns = column_values)

  # find table rows and add to dataframe 
  try:
    rows = detail_page.find('table', class_='items').find('tbody').find_all('tr')
    for row in rows:
      table_row = []
      table_row.append(id)
      for section in row.find_all('td'):
        if section.text !='':
          table_row.append(section.text)
        else:
          try:
            table_row.append(section.a['title'])
          except:
            continue
      detail_table.loc[len(detail_table.index)]= table_row  
  except:
    print(detail_link_format.format(id)+" table row not found!")

  return detail_table

# %%
id = ['357885', '120629']
table = pd.DataFrame()
for i in id:
  table = pd.concat([table, test(i)], axis=0)
table.head
table.to_csv('stat_test1.csv', encoding='utf-8')

# %% [markdown]
# ## Creting Test .csv files

# %%
# find the first two league of each season for test
def first_two_league (link):
  page = requests.get(link, headers=headers)
  page = BeautifulSoup(page.content, 'html.parser')
  #page.prettify
  leagues_link = []
  leagues={'First Tier'}
  tr_tags= page.find('table', class_= 'items').find('tbody').find_all('tr')
  flag = 2
  #for tr in tr_tags:

  for i, tr in enumerate(tr_tags):  
    #if i >1: 
      #break
    if(tr.find('td',class_='extrarow bg_blau_20 hauptlink') and tr.find('td',class_='extrarow bg_blau_20 hauptlink').text not in leagues):
      #print(tr.find('td',class_='extrarow bg_blau_20 hauptlink').text)
      flag =0
    elif (tr.find('td',class_='extrarow bg_blau_20 hauptlink') and tr.find('td',class_='extrarow bg_blau_20 hauptlink').text in leagues):
      flag = 1
    #if(tr.find('td', class_='hauptlink').find('tbody')):
    if(flag):
      try:
        lg_link = tr.find('td', class_='hauptlink').find('a')['href']
        #print(lg_link)
        leagues_link.append('https://www.transfermarkt.com'+lg_link)
      except:
        continue
  return leagues_link

# %%
#find the first three team of each league for test
def first_three_team(link): #link of the league teams page
  page = requests.get(link, headers=headers)
  page = BeautifulSoup(page.content, 'html.parser')
  try:
    team_tag = page.find('table', class_='items').find('tbody').find_all('tr')
  except:
    print(link+ ' team table not found!')
  team_link =[]
  for i, tr in enumerate(team_tag):
    if i>2:
      break

    try:
      team_link.append('https://www.transfermarkt.com'+tr.find('td').find_next('td').find('a')['href'])
    except:
      print(link+ ' team link not found')
      team_link.append(np.nan)
  
  return team_link

# %%
# find first 10 players link by team link
def first_ten_players(link): 
  page = requests.get(link, headers=headers)
  time.sleep(2)
  page = BeautifulSoup(page.content, 'html.parser')

  players_link=[]
  player_tag = page.find('table', class_='items').find('tbody').find_all('tr')
  for tr in player_tag:
    if len(players_link)>9:
      break
    try:
      player_link= tr.find('table', class_='inline-table').find('td', class_='hauptlink').find('div', class_='di nowrap').find('a')['href']
      players_link.append('https://www.transfermarkt.com'+ player_link)
    except:
      #print('player link not found')
      continue
    #print(player_name)
  
  return players_link

# %%
country_season_link_format = 'https://www.transfermarkt.com/wettbewerbe/national/wettbewerbe/{}/saison_id/{}/plus/1'
#country_id = {'189', '50', '157', '40', '75'} #England, France, Spain, Germany, Italy
country_id = {'189'} #England, France
season = {'2021'}

#link variables
all_season_leagues=[]
all_league_teams={}
all_team_players={}

#test variables
player_ids=[]
player_count=0

#final tables culomns & Each player's table
player_table_culomns = ['player_id', 'name', 'birth_date', 'height', 'current_international', 'main_position', 'foot', 'current_club', 'goals_scored', 'goals_assisted', 'goals_conceded', 'clean_sheets', 'total_appearence', 'agent']
transfer_table_culomns = ['player_id', 'Season', 'Date', 'Left', 'Joined', 'MV', 'Fee']

player = pd.DataFrame(columns = player_table_culomns)
transfer = pd.DataFrame(columns = transfer_table_culomns)
statistics= pd.DataFrame()

#final tables (all datas from players)
player_table = pd.DataFrame(columns = player_table_culomns)
transfer_table = pd.DataFrame(columns = transfer_table_culomns)
statistics_table= pd.DataFrame()


for c_id in tqdm(country_id, desc ="countries"):
  
  for i, s_id in enumerate(season):
    link = country_season_link_format.format(c_id, s_id)
    
    all_season_leagues=(first_two_league(link))
    #print('----- leagues links',all_season_leagues)
    
    for league_link in tqdm(all_season_leagues, desc='leagues'):
      #print(league_link)
      all_league_teams=(first_three_team(league_link))
      
      for team_link in tqdm(all_league_teams, desc='teams'):  
       
        all_team_players=(first_ten_players(team_link))
        for player_link in (all_team_players):
        
          try:
            if player_id(player_link) not in player_ids:
              player_count+=1
              #print ('new id added','   ',player_count,'  ', player_id(player_link))
              player_ids.append(player_id(player_link))
              player, transfer, statistics = find_player_info(player_link)
              
              player_table.loc[len(player_table.index)]= player
              transfer_table = pd.concat([transfer_table, transfer], axis=0)
              statistics_table= pd.concat([statistics_table, statistics], axis=0)
            else:
              print(player_link + ' duplicate id found and skiped')
            continue
          except:
            print(player_link + ' something wrong and skiped')           
            continue
          


player_table.to_csv('player_table.csv', encoding='utf-8')
transfer_table.to_csv('trasnfer_table.csv', encoding='utf-8')
statistics_table.to_csv('statistics_table V2.csv', encoding='utf-8')
#df.to_csv(file_name, sep='\t', encoding='utf-8')
# Out:
# countries:   0%|          | 0/1 [00:00<?, ?it/s]
# leagues:   0%|          | 0/1 [00:00<?, ?it/s]
# teams:   0%|          | 0/3 [00:00<?, ?it/s]
# https://www.transfermarkt.com/cieran-slicker/profil/spieler/621997 player height not found!
# https://www.transfermarkt.com/cieran-slicker/profil/spieler/621997 player foot not found!
# https://www.transfermarkt.com/aymeric-laporte/profil/spieler/176553 player agent not found!
# https://www.transfermarkt.com/cj-egan-riley/profil/spieler/581669 player agent not found!
# https://www.transfermarkt.com/marcelo-pitaluga/profil/spieler/662334 player agent not found!
# https://www.transfermarkt.com/ruben-dias/leistungsdatendetails/spieler/494284/saison//verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 table row not found!
# https://www.transfermarkt.com/kurt-zouma/profil/spieler/157509 player agent not found!

# %% [markdown]
# ## test area for test tables
